# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"]="0"

from huggingface_hub import login
login(token="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")

MODEL="bigcode/starcoderbase-1b" # Model checkpoint on the Hugging Face Hub
DATASET="smangrul/hf-stack-v1"   # Dataset on the Hugging Face Hub
DATA_COLUMN="content"            # Column name containing the code content
OUTPUT_DIR="models"
OUTPUT_DIR_1="peft-starcoder-lora-a100"
SEED=0

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    Trainer,
    TrainingArguments,
    logging,
    set_seed,
    BitsAndBytesConfig
)
set_seed(SEED)


from peft import PeftModel

import torch
torch.cuda.empty_cache()


# load the original model first
tokenizer = AutoTokenizer.from_pretrained(MODEL, trust_remote_code=True)
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL,
    quantization_config=None,
    device_map=None,
    trust_remote_code=True,
    torch_dtype=torch.bfloat16,
).cuda()

# merge fine-tuned weights with the base model
peft_model_id = f"marijajolovic/{OUTPUT_DIR}/{OUTPUT_DIR_1}"
model = PeftModel.from_pretrained(base_model, peft_model_id)
model.merge_and_unload()

def get_code_completion(prefix, suffix):
    text = prompt = f"""<fim_prefix>{prefix}<fim_suffix>{suffix}<fim_middle>"""
    model.eval()
    outputs = model.generate(
        input_ids=tokenizer(text, return_tensors="pt").input_ids.cuda(),
        max_new_tokens=128,
        temperature=0.2,
        top_k=50,
        top_p=0.95,
        do_sample=True,
        repetition_penalty=1.0,
    )
    return tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

prefix = """from peft import LoraConfig, TaskType, get_peft_model
from transformers import AutoModelForCausalLM
peft_config = LoraConfig(
"""
suffix =""""""

print(get_code_completion(prefix, suffix))
# Out:
# 2025-02-25 12:16:20.916154: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-25 12:16:20.944368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740485780.972257  238922 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740485780.980792  238922 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-25 12:16:21.013742: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tokenizer_config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/777k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/442k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/532 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/myenv/lib/python3.10/site-packages/peft/config.py:257, in PeftConfigMixin._get_peft_type(cls, model_id, **hf_hub_download_kwargs)
#     256 try:
# --> 257     config_file = hf_hub_download(
#     258         model_id,
#     259         CONFIG_NAME,
#     260         **hf_hub_download_kwargs,
#     261     )
#     262 except Exception:
#
# File ~/myenv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/myenv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'marijajolovic/models/peft-starcoder-lora-a100'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 45
#      43 # merge fine-tuned weights with the base model
#      44 peft_model_id = f"marijajolovic/{OUTPUT_DIR}/{OUTPUT_DIR_1}"
# ---> 45 model = PeftModel.from_pretrained(base_model, peft_model_id)
#      46 model.merge_and_unload()
#      48 def get_code_completion(prefix, suffix):
#
# File ~/myenv/lib/python3.10/site-packages/peft/peft_model.py:479, in PeftModel.from_pretrained(cls, model, model_id, adapter_name, is_trainable, config, autocast_adapter_dtype, ephemeral_gpu_offload, low_cpu_mem_usage, **kwargs)
#     476 # load the config
#     477 if config is None:
#     478     config = PEFT_TYPE_TO_CONFIG_MAPPING[
# --> 479         PeftConfig._get_peft_type(
#     480             model_id,
#     481             subfolder=kwargs.get("subfolder", None),
#     482             revision=kwargs.get("revision", None),
#     483             cache_dir=kwargs.get("cache_dir", None),
#     484             use_auth_token=kwargs.get("use_auth_token", None),
#     485             token=kwargs.get("token", None),
#     486         )
#     487     ].from_pretrained(model_id, **kwargs)
#     488 elif isinstance(config, PeftConfig):
#     489     config.inference_mode = not is_trainable
#
# File ~/myenv/lib/python3.10/site-packages/peft/config.py:263, in PeftConfigMixin._get_peft_type(cls, model_id, **hf_hub_download_kwargs)
#     257         config_file = hf_hub_download(
#     258             model_id,
#     259             CONFIG_NAME,
#     260             **hf_hub_download_kwargs,
#     261         )
#     262     except Exception:
# --> 263         raise ValueError(f"Can't find '{CONFIG_NAME}' at '{model_id}'")
#     265 loaded_attributes = cls.from_json_file(config_file)
#     266 return loaded_attributes["peft_type"]
#
# ValueError: Can't find 'adapter_config.json' at 'marijajolovic/models/peft-starcoder-lora-a100'
